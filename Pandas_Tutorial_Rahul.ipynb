# %%
import pandas as pd
import numpy as np
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
person= {
    "Index":["A","B","C","D","E","F","G","H","I","J"],
    "Name":["Rahul","Ravi","Suraj","Vivek","Manish","Raju","Pratik","Prince","Raja","Lokesk"],
    "Age":[28,29,30,25,28,35,32,31,3,40],
    "City":["Ghazibad","Delhi","Noida","Nke","Motohari","Nke","Patna","Nke","Ramnagar","Patna"],
    "Bick":["Rider","Heropuch","Bulate","Apachi","Hero","Tvs","Bajaj","Yamha","Honda","Tvs"],
    "Mob":[54613,65423,1354,45697,12354,1254,4655,4687,2542,40124]
}

# %%
Df=pd.DataFrame(person)

# %%
Df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Index   10 non-null     object
#  1   Name    10 non-null     object
#  2   Age     10 non-null     int64
#  3   City    10 non-null     object
#  4   Bick    10 non-null     object
#  5   Mob     10 non-null     int64
# dtypes: int64(2), object(4)
# memory usage: 608.0+ bytes

# %%
Df["Name"]
# Out:
# 0     Rahul
# 1      Ravi
# 2     Suraj
# 3     Vivek
# 4    Manish
# 5      Raju
# 6    Pratik
# 7    Prince
# 8      Raja
# 9    Lokesk
# Name: Name, dtype: object

# %%
Df
# Out:
#   Index    Name  Age      City      Bick    Mob
# 0     A   Rahul   28  Ghazibad     Rider  54613
# 1     B    Ravi   29     Delhi  Heropuch  65423
# 2     C   Suraj   30     Noida    Bulate   1354
# 3     D   Vivek   25       Nke    Apachi  45697
# 4     E  Manish   28  Motohari      Hero  12354
# 5     F    Raju   35       Nke       Tvs   1254
# 6     G  Pratik   32     Patna     Bajaj   4655
# 7     H  Prince   31       Nke     Yamha   4687
# 8     I    Raja    3  Ramnagar     Honda   2542
# 9     J  Lokesk   40     Patna       Tvs  40124

# %%
type(Df)
# Out:
# pandas.core.frame.DataFrame

# %%
Df.describe()#Onlt int Value Show
# Out:
#              Age           Mob
# count  10.000000     10.000000
# mean   28.100000  23270.300000
# std     9.757618  25280.552842
# min     3.000000   1254.000000
# 25%    28.000000   3070.250000
# 50%    29.500000   8520.500000
# 75%    31.750000  44303.750000
# max    40.000000  65423.000000

# %%
Df.head()
# Out:
#   Index    Name  Age      City      Bick    Mob
# 0     A   Rahul   28  Ghazibad     Rider  54613
# 1     B    Ravi   29     Delhi  Heropuch  65423
# 2     C   Suraj   30     Noida    Bulate   1354
# 3     D   Vivek   25       Nke    Apachi  45697
# 4     E  Manish   28  Motohari      Hero  12354

# %%
Df.head(2)
# Out:
#   Index   Name  Age      City      Bick    Mob
# 0     A  Rahul   28  Ghazibad     Rider  54613
# 1     B   Ravi   29     Delhi  Heropuch  65423

# %%
Df[["Name","City","Mob"]]#Paticular columns Show
# Out:
#      Name      City    Mob
# 0   Rahul  Ghazibad  54613
# 1    Ravi     Delhi  65423
# 2   Suraj     Noida   1354
# 3   Vivek       Nke  45697
# 4  Manish  Motohari  12354
# 5    Raju       Nke   1254
# 6  Pratik     Patna   4655
# 7  Prince       Nke   4687
# 8    Raja  Ramnagar   2542
# 9  Lokesk     Patna  40124

# %%
#iloc Function Raw & coulmns fetch 
Df.iloc[0]#0 Only Row Show
# Out:
# Index           A
# Name        Rahul
# Age            28
# City     Ghazibad
# Bick        Rider
# Mob         54613
# Name: 0, dtype: object

# %%
Df.iloc[1:5]
# Out:
#   Index    Name  Age      City      Bick    Mob
# 1     B    Ravi   29     Delhi  Heropuch  65423
# 2     C   Suraj   30     Noida    Bulate   1354
# 3     D   Vivek   25       Nke    Apachi  45697
# 4     E  Manish   28  Motohari      Hero  12354

# %%
Df.iloc[3:,2]#Row & Columns fetch
# Out:
# 3    25
# 4    28
# 5    35
# 6    32
# 7    31
# 8     3
# 9    40
# Name: Age, dtype: int64

# %%
Df.iloc[2:,[1,3]]
# Out:
#      Name      City
# 2   Suraj     Noida
# 3   Vivek       Nke
# 4  Manish  Motohari
# 5    Raju       Nke
# 6  Pratik     Patna
# 7  Prince       Nke
# 8    Raja  Ramnagar
# 9  Lokesk     Patna

# %%
#Filtering dataframe
mask=Df['City']=="Nke"

# %%
mask #bol Series
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# 7     True
# 8    False
# 9    False
# Name: City, dtype: bool

# %%
Df[mask]
# Out:
#   Index    Name  Age City    Bick    Mob
# 3     D   Vivek   25  Nke  Apachi  45697
# 5     F    Raju   35  Nke     Tvs   1254
# 7     H  Prince   31  Nke   Yamha   4687

# %%
Df[mask].shape[0]#count city
# Out:
# 3

# %%
#this work function type
def get_city_count(City):
  mask=Df['City']==City
  return Df[mask].shape[0]

# %%
get_city_count("Patna")
# Out:
# 2

# %%
data=pd.read_csv("/content/drive/MyDrive/Data/matches - matches.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
data.head(10)
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 6   7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 7   8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 8   9    2017       Pune  2017-04-11             Delhi Daredevils
# 9  10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %%
data.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
data.iloc[:,[2,4,5,10]]
# Out:
#           city                        team1                        team2  \
# 0    Hyderabad          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1         Pune               Mumbai Indians       Rising Pune Supergiant
# 2       Rajkot                Gujarat Lions        Kolkata Knight Riders
# 3       Indore       Rising Pune Supergiant              Kings XI Punjab
# 4    Bangalore  Royal Challengers Bangalore             Delhi Daredevils
# ..         ...                          ...                          ...
# 631     Raipur             Delhi Daredevils  Royal Challengers Bangalore
# 632  Bangalore                Gujarat Lions  Royal Challengers Bangalore
# 633      Delhi          Sunrisers Hyderabad        Kolkata Knight Riders
# 634      Delhi                Gujarat Lions          Sunrisers Hyderabad
# 635  Bangalore          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                           winner
# 0            Sunrisers Hyderabad
# ...

# %%
mask=data["city"]=="Hyderabad"
data[mask].shape
# Out:
# (49, 18)

# %%
def get_city_count(city):
  mask=data["city"]==city
  return data[mask].shape[0]

# %%
get_city_count("Pune")
# Out:
# 32

# %%
mask1=data["team1"]=="Sunrisers Hyderabad"
mask2=data["team2"]=="Kings XI Punjab"
data[mask1 & mask2].shape[0]
# Out:
# 6

# %%
def get_team_withplay_otherteam_count(team1,team2):
  mask1=data["team1"]==team1
  mask2=data["team2"]==team2
  return data[mask1 & mask2].shape[0]

# %%
 get_team_withplay_otherteam_count("Delhi Daredevils","Kings XI Punjab")
# Out:
# 10

# %%
data["winner"].value_counts()
# Out:
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: winner, dtype: int64

# %%
#pandas plot()
import matplotlib.pyplot as plt

data["winner"].value_counts().plot(kind="barh")

# %%
data["toss_decision"].value_counts()
# Out:
# field    363
# bat      273
# Name: toss_decision, dtype: int64

# %%
data["toss_decision"].value_counts().plot(kind="pie")

# %%
data["win_by_runs"].plot(kind="hist")

# %%
#
play_match=(data["team1"].value_counts() + data["team2"].value_counts()).sort_values(ascending=False)
play_match
# Out:
# Mumbai Indians                 157
# Royal Challengers Bangalore    152
# Kings XI Punjab                148
# Kolkata Knight Riders          148
# Delhi Daredevils               147
# Chennai Super Kings            131
# Rajasthan Royals               118
# Sunrisers Hyderabad             76
# Deccan Chargers                 75
# Pune Warriors                   46
# Gujarat Lions                   30
# Rising Pune Supergiant          16
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# dtype: int64

# %%
data.sort_values(['win_by_runs','season'],ascending=[True,True]).head(10)
# Out:
#     id  season        city        date                        team1  \
# 61  62    2008       Delhi  2008-04-19             Rajasthan Royals
# 62  63    2008      Mumbai  2008-04-20               Mumbai Indians
# 63  64    2008     Kolkata  2008-04-20              Deccan Chargers
# 64  65    2008      Jaipur  2008-04-21              Kings XI Punjab
# 65  66    2008   Hyderabad  2008-04-22              Deccan Chargers
# 67  68    2008   Hyderabad  2008-04-24              Deccan Chargers
# 69  70    2008   Bangalore  2008-04-26  Royal Challengers Bangalore
# 70  71    2008     Chennai  2008-04-26        Kolkata Knight Riders
# 71  72    2008      Mumbai  2008-04-27               Mumbai Indians
# 72  73    2008  Chandigarh  2008-04-27             Delhi Daredevils
#
#                           team2            toss_winner toss_decision  result  \
# 61             Delhi Daredevils       Rajasthan Royals           bat  normal
# ...

# %%
data.head(5)
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
data.shape
# Out:
# (636, 18)

# %%
data.drop_duplicates("city").shape
# Out:
# (31, 18)

# %%
data.drop_duplicates('season',keep='last')[['season','winner','win_by_runs','win_by_wickets']].sort_values('season')
# Out:
#      season                 winner  win_by_runs  win_by_wickets
# 116    2008       Rajasthan Royals            0               3
# 173    2009        Deccan Chargers            6               0
# 233    2010    Chennai Super Kings           22               0
# 306    2011    Chennai Super Kings           58               0
# 380    2012  Kolkata Knight Riders            0               5
# 456    2013         Mumbai Indians           23               0
# 516    2014  Kolkata Knight Riders            0               3
# 575    2015         Mumbai Indians           41               0
# 635    2016    Sunrisers Hyderabad            8               0
# 58     2017         Mumbai Indians            1               0

# %% [markdown]
# # New Section
